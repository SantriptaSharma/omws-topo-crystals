# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np

# %%
t50 = np.load("data/predict_feature_topo_compo_cv_50.npz")
t500 = np.load("data/predict_feature_topo_compo_cv_500.npz")
t5000 = np.load("data/predict_feature_topo_compo_cv_5000.npz")

# %%
t50["time"]/60, t500["time"]/60, t5000["time"]/60
# Out:
# (np.float64(1.124074761666672),
#  np.float64(5.438563914999993),
#  np.float64(45.237728284999996))

# %%
t50["r2"], t500["r2"], t5000["r2"]
# Out:
# (array(0.07715095), array(0.53338639), array(0.95977993))
